# %% [markdown]
# ### Import pysammos

# %%
import os
os.environ["NUMBA_NUM_THREADS"] = "8"
print(f">>> Numba is using {os.environ['NUMBA_NUM_THREADS']} cores")
# Out:
# >>> Numba is using 8 cores

# %%
import numpy as np

# %%
from pysammos.utils.config_loader import load_config
from pysammos.coarse_graining import CoarseGraining
# Out:
# Hello from pysammos
# Loading macroscopic_fields package...
# Loading data_read package...
# Loading particle_phase package...
# Loading spatial_weights package...
# Loading neighbour_search package...
# Loading grid_generation package...
# Loading data_handle package...
# Loading data_write package...

# %% [markdown]
# ### Run Coarse - Graining Workflow

# %% [markdown]
# Initialise the Coarse Graining class

# %%
# Load the configuration from the ini file
cfg = load_config("config.ini")  
print("-------------------- config.ini file read --------------------")
# Initialize the CoarseGraining class with the loaded configuration
CG = CoarseGraining(
    particle_path=cfg["particles_path"],
    contacts_path=cfg["contacts_path"],
    output_path=cfg["output_path"],
    start_timestep=cfg["t0"],
    end_timestep=cfg["tf"],
    dt_time_step=cfg["dt"],
    DEM_keymap=cfg["key_mapping"],
    grid_info=cfg["grid_info"],
    weight_function=cfg["smoothing_function"],
    fields_to_export=cfg["fields_to_export"],
    ignore_phases=cfg["partialignore"],
    h5_output=cfg["h5_output"],
    vkthdf_output=cfg["vkthdf_output"],
                    ) 
print("  ") ; print("-------------------- CoarseGraining class initialised --------------------")
# Out:
# -------------------- config.ini file read --------------------
# Output path created: ./PysammosCG/
#
# -------------------- CoarseGraining class initialised --------------------

# %% [markdown]
# Option (A) Run all at once:

# %%
#CG.run()

# %% [markdown]
# Option (B) Run step by step:

# %%
# 1. Load the size-relevant particle data for the first time step
Bounds_t0, Diameter_t0, Density_t0, Mass_t0, GlobalID_t0 = CG.data_sampling()
# Out:
# XML-based PolyData detected.

# %%
# 2. Calculate the particle size range
CG.get_particle_size_statistics(Diameter_t0, Mass_t0)
print(">> Particle size statistics: ") 
print("       d43: ", CG.d43)
print("       dmax: ", CG.dmax)
print("       d50: ", CG.d50)
print("       d32: ", CG.d32)
print("       drms: ", CG.drms)
# Out:
# >> Particle size statistics:
#        d43:  0.0017099578457783194
#        dmax:  0.001709958
#        d50:  0.001709958
#        d32:  0.0017099580559647798
#        drms:  0.001709957928496767

# %%
# 3. Get the phases
CG.get_particle_phases(Diameter_t0, Density_t0, GlobalID_t0, 8)
print(">> Phases: ")
print("       Diameters: ", CG.phases[:,0])
print("       Densities: ", CG.phases[:,1])
# Out:
# Ignoring phases. Using mean density and d50 as phase.
# >> Phases:
#        Diameters:  [0.00170996]
#        Densities:  [2560.]

# %%
# 4. Calculate the CG grid spacing
CG.set_resolution(2.5*CG.d43) # here you can input different number, to make w and c bigger or smaller 
print(">> Coarse Graining resolution: ")
print("       c:", CG.c)
print("       w:", CG.w)
# Out:
# >> Coarse Graining resolution:
#        c: 0.006412341921668698
#        w: 0.003206170960834349

# %%
# 5. Generate the CG grid
CG.generate_grid()
print(">> Grid: ")
print("       Grid Points: ", CG.GridPoints.shape, "First Point: ", CG.GridPoints[0])
print("       Nodes: ", CG.Nodes)
print("       Spacing: ", CG.Spacing)
# Out:
# Generating Grid with Customised Grid Ranges
# Customised grid bounds: x = [0.002, 0.018], y = [0.0, 0.05], z = [0.0, 0.008], x_transect = None, y_transect = None, z_transect = None
# >> Grid:
#        Grid Points:  (408, 3) First Point:  [0.002 0.    0.   ]
#        Nodes:  [ 6 17  4]
#        Spacing:  [0.0032     0.003125   0.00266667]

# %%
# 6. Calculate the CG fields
CG.fields_in_time()
# Out:
#
# -------------------- Calculating Coarse Grained Fields --------------------
#
# ---> Time step 0: time 0036 ................................................
# Loading data ...
#   Particle data loaded
#   Repeated pairs in contact data:  82
#   Contact data loaded and mapped
#   Coordination number not provided. Calculating it.
# ... data loaded
# Matching particles to grid points ...
# ... particles assigned to grid nodes
# Computing weights ...
#   Using Lucy kernel with cutoff 0.006412341921668698 and search sampling factor 1000
# ... weights computed
# Computing Coarse Graining fields...
#   volume fraction done
#   mixture density done
#   momentum density done
#   velocity done
#   velocity gradient done
#   kinetic tensor done
#   contact tensor done
#   particle density done
#   total stress done
#   d43 done
#   d32 done
#   Z done
#   pressure done
#   granular temp done
#   shear rate done
#   inertial number done
#   mu done
# ... fields computed
# Writing results for timestep 36...
#   File successfully updated to ./PysammosCG/CG_Lucy_Monodisperse.h5
#   File successfully written to ./PysammosCG/CG_Lucy_Monodisperse_0036.vtkhdf
# ... results written
#   File successfully updated to ./PysammosCG/CG_GranularTemperature_slices.h5
#   File successfully written to ./PysammosCG/CG_GranularTemperature_slices.h5
# >> time step 0 took 7.661705732345581 to run.
#
# ---> Time step 1: time 0037 ................................................
# Loading data ...
#   Particle data loaded
#   Repeated pairs in contact data:  99
#   Contact data loaded and mapped
#   Coordination number not provided. Calculating it.
# ... data loaded
# Matching particles to grid points ...
# ... particles assigned to grid nodes
# Computing weights ...
#   Using Lucy kernel with cutoff 0.006412341921668698 and search sampling factor 1000
# ... weights computed
# Computing Coarse Graining fields...
#   volume fraction done
#   mixture density done
#   momentum density done
#   velocity done
#   velocity gradient done
#   kinetic tensor done
#   contact tensor done
#   particle density done
#   total stress done
#   d43 done
#   d32 done
#   Z done
#   pressure done
#   granular temp done
#   shear rate done
#   inertial number done
#   mu done
# ... fields computed
# Writing results for timestep 37...
#   File successfully updated to ./PysammosCG/CG_Lucy_Monodisperse.h5
#   File successfully written to ./PysammosCG/CG_Lucy_Monodisperse_0037.vtkhdf
# ... results written
#   File successfully updated to ./PysammosCG/CG_GranularTemperature_slices.h5
#   File successfully written to ./PysammosCG/CG_GranularTemperature_slices.h5
# >> time step 1 took 0.3258514404296875 to run.
#
# ---> Time step 2: time 0038 ................................................
# Loading data ...
#   Particle data loaded
#   Repeated pairs in contact data:  89
#   Contact data loaded and mapped
#   Coordination number not provided. Calculating it.
# ... data loaded
# Matching particles to grid points ...
# ... particles assigned to grid nodes
# Computing weights ...
#   Using Lucy kernel with cutoff 0.006412341921668698 and search sampling factor 1000
# ... weights computed
# Computing Coarse Graining fields...
#   volume fraction done
#   mixture density done
#   momentum density done
#   velocity done
#   velocity gradient done
#   kinetic tensor done
#   contact tensor done
#   particle density done
#   total stress done
#   d43 done
#   d32 done
#   Z done
#   pressure done
#   granular temp done
#   shear rate done
#   inertial number done
#   mu done
# ... fields computed
# Writing results for timestep 38...
#   File successfully updated to ./PysammosCG/CG_Lucy_Monodisperse.h5
#   File successfully written to ./PysammosCG/CG_Lucy_Monodisperse_0038.vtkhdf
# ... results written
#   File successfully updated to ./PysammosCG/CG_GranularTemperature_slices.h5
#   File successfully written to ./PysammosCG/CG_GranularTemperature_slices.h5
# >> time step 2 took 0.3294374942779541 to run.
